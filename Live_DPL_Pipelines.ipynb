# %%
import pandas as pd
import numpy as np
from dateutil.parser import parse
from datetime import datetime
import csv
import matplotlib.pyplot as plt
import math
import matplotlib.ticker
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import geopy.distance

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df = pd.read_csv('gs://aes-analytics-0001-curated/Outage_Restoration/DPL/TCMS/ERT_Live/ETR_predictions.csv')

# %%
df.head()
# Out:
#    OUTAGE_ID   TIME_OF_FIRST_CALL Estimated_Restoration_Time  ETR_Minutes Weather_Profile
# 0    1416835  2020-12-16 02:39:01        2020/12/16 06:30:00        232.0       Clear Sky

# %%
df1 = pd.read_csv('gs://aes-analytics-0001-curated/Outage_Restoration/DPL/TCMS/Circuit_ERT_Live/Circuit_ERT_Predictions.csv')

# %%
df1.head()
# Out:
#    SUBSOTG_ID     DATETIMESTART  ETR_Minutes Estimated_Restoration_Time Weather_Profile
# 0      267729  12/11/2020 10:27           57           12/11/2020 11:24       Clear Sky
