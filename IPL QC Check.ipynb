# %%
import pandas as pd
import numpy as np
from dateutil.parser import parse
from datetime import datetime
from datetime import date
import csv
import matplotlib.pyplot as plt
import math
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
from IPython.display import display_html
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df_facility_job_his = pd.read_csv('gs://aes-datahub-0001-raw/OMS/2002-2020/IPL/HIS_FACILITY_JOB_IPL.csv', sep = ",", encoding = "ISO-8859-1")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-271b011a4627> in <module>
# ----> 1 df_facility_job_his = pd.read_csv('gs://aes-datahub-0001-raw/OMS/2002-2020/IPL/HIS_FACILITY_JOB_IPL.csv', sep = ",", encoding = "ISO-8859-1")
#
# ...

# %%
df_facility_job_his.head()
# Out:
#   FAC_JOB_ID|CIRCT_ID|MAJ_OTG_ID|EQUIP_STN_NO|DIST_NO|HOST_SEQ_ID|PRIORITY_VAL|CUST_QTY|CLUE_CD|CLUE_DESC|CREATION_DATETIME|CALL_QTY|KEY_CUST_QTY|SPLIT_FAC_JOB_FLG|CAUSE_CD|CAUSE_DESC|OCCURN_CD|OCCURN_DESC|CLIMATIC_CD|CLIMATIC_DESC|CITY_NAM|LOC_DESC|WRK_ORD_NUM|COMMENT_TEXT|CALL_ID|KVA_VAL|BOOK_NO|ADDRESS|CIRCT_NAM|CLUE_CD2|INSERTED_DATE|DOWNSTREAM_KVA_VAL|DOWNSTREAM_CUST_QTY|COMPL_DATETIME|TOT_LOSS_POWER_FLG|ISOLATED_TO_CUST_FLG|PLANNED_OUTAGE_FLG|ROUTINE_FLG|DNI_EQUIP_TYPE|SUBST_ID|WORK_ORD_1_NO|WORK_ORD_2_NO|WORK_ORD_3_NO|WORK_ORD_4_NO|WORK_ORD_5_NO|ENERGIZED_DATETIME|DISPLAY_TEXT|POLICE_OPERATOR_ID|POLICE_INC_NO|FIRE_OPERATOR_ID|FIRE_INC_NO|CAD_ID|STRCTUR_NO|FAC_JOB_PARENT_ID|MAJ_INCIDENT_FLG|MAJ_INCIDENT_CAUSE|ZONE_DESC|DIST_DESC|ZONE_ID|GEO_DIST_NO|ETR_DATETIME|SUBST_SHUTDOWN_FLG|HIS_FAC_JOB_COMMENT|CIRCT_DESC|SUBST_DESC|DCNID_VAL|CREW_REMARKS|INCIDENT_ID|CLUE_DESC2|DIST_ABBREV
# 0  2000152777|"2867"|""|"2818970_A"|"01"|""|"9"|"...
# ...

# %%
#incdev_df = pd.read_csv('gs://aes-datahub-0001-raw/OMS/2020-07-13/INCIDENT_DEVICE_IPL_202007151300.csv', sep = ',', encoding = 'ISO-8859-1')
inc_df = pd.read_csv('gs://aes-datahub-0001-raw/OMS/2020-07-15/INCIDENT_IPL_202007151300.csv', sep = ',', encoding = 'ISO-8859-1')
#loc_df = pd.read_csv('gs://aes-datahub-0001-raw/OMS/2020-07-13/LOCATION_IPL_202007151300.csv', sep = ',', encoding = 'ISO-8859-1')

# %%
print(incdev_df.INCIDENT_DEVICE_ID.nunique())
print(incdev_df.INCIDENT_ID.nunique())
print(incdev_df.STRCTUR_NO.nunique())
print(incdev_df.CIRCT_ID.nunique())
print(incdev_df.DNI_EQUIP_TYPE.nunique())
# Out:
# 540
# 522
# 461
# 193
# 16

# %%
print(inc_df.INCIDENT_ID.nunique())
print(inc_df.LOCATION_ID.nunique())
# Out:
# 314
# 314

# %%
print(loc_df.INCIDENT_ID.nunique())
print(loc_df.LOCATION_ID.nunique())
print(loc_df.INCIDENT_DEVICE_ID.nunique())
# Out:
# 525
# 531
# 531

# %%
hisincident_df = pd.read_csv('gs://aes-datahub-0001-raw/OMS/2002-2020/IPL/HIS_INCIDENT_IPL.csv', sep = '|', encoding = 'ISO-8859-1')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-1b2ff5b44c59> in <module>
# ----> 1 hisincident_df = pd.read_csv('gs://aes-datahub-0001-raw/OMS/2002-2020/IPL/HIS_INCIDENT_IPL.csv', sep = '|', encoding = 'ISO-8859-1')
#
# ...

# %%
hisincident_df['CREATION_DATETIME'] = pd.to_datetime(hisincident_df['CREATION_DATETIME'], infer_datetime_format = True, errors = 'coerce')

# %%
hisincident_df = hisincident_df[hisincident_df['CREATION_DATETIME'] >= '01-01-2010 00:00:00']
hisincident_df = hisincident_df[hisincident_df['CREATION_DATETIME'] <= '01-01-2020 00:00:00']

# %%
print(hisincident_df.INCIDENT_ID.nunique())
print(hisincident_df.LOCATION_ID.nunique())
# Out:
# 249681
# 249680

# %%
hisincident_df.INCIDENT_ID.count()
# Out:
# 749043

# %%
hisfacjob_df = pd.read_csv('gs://aes-datahub-0001-raw/OMS/2002-2020/IPL/HIS_FACILITY_JOB_IPL.csv', sep = '|', encoding = 'ISO-8859-1')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-17-53431131b393> in <module>
# ----> 1 hisfacjob_df = pd.read_csv('gs://aes-datahub-0001-raw/OMS/2002-2020/IPL/HIS_FACILITY_JOB_IPL.csv', sep = '|', encoding = 'ISO-8859-1')
#
# ...

# %%
hisfacjob_df['CREATION_DATETIME'] = pd.to_datetime(hisfacjob_df['CREATION_DATETIME'], errors = 'coerce')

# %%
hisfacjob_df['Date'] = hisfacjob_df['CREATION_DATETIME'].dt.date

# %%
hisfacjob_df['Date'] = pd.to_datetime(hisfacjob_df['Date'])

# %%
tempdf = hisfacjob_df

# %%
tempdf = tempdf[(tempdf['Date'] >= pd.to_datetime('2020-01-01')) & (tempdf['Date'] < pd.to_datetime('2020-01-01'))]

# %%
print(tempdf.FAC_JOB_ID.nunique())
print(tempdf.INCIDENT_ID.nunique())
print(tempdf.STRCTUR_NO.nunique())
print(tempdf.CIRCT_ID.nunique())
print(tempdf.DNI_EQUIP_TYPE.nunique())
# Out:
# 725947
# 640256
# 98639
# 461
# 34

# %%
df_incident = pd.read_csv('gs://aes-datahub-0001-raw/OMS/2002-2020/IPL/HIS_INCIDENT_IPL.csv', sep='|', encoding = "ISO-8859-1")

# %%
df_incident['CREATION_DATETIME'] = pd.to_datetime(df_incident['CREATION_DATETIME'],errors='coerce')
df_incident['Date'] = df_incident['CREATION_DATETIME'].dt.date

# %%
#df_incident = df_incident[(df_incident['Date'] >= pd.to_datetime('2010-01-01')) & (df_incident['Date'] < pd.to_datetime('2020-01-01'))]

# %%
df_incident = df_incident[df_incident['Date'] >= pd.to_datetime('2020-01-01')]

# %%
print(df_incident.INCIDENT_ID.nunique())
print(df_incident.LOCATION_ID.nunique())
# Out:
# 32085
# 32085

# %%
del df_incident

# %%
df_location = pd.read_csv('gs://aes-datahub-0001-raw/OMS/2002-2020/IPL/HIS_LOCATION_IPL.csv', sep = '|', encoding = "ISO-8859-1")

# %%
df_location['Date'] = pd.to_datetime(df_location['CREATION_DATETIME']).dt.date
df_location['Date'] = pd.to_datetime(df_location['Date'])

# %%
df_location = df_location[df_location['Date'] >= pd.to_datetime('2020-01-01')]

# %%
print(df_location.INCIDENT_ID.nunique())
print(df_location.LOCATION_ID.nunique())
print(df_location.INCIDENT_DEVICE_ID.nunique())
# Out:
# 32132
# 36291
# 36291

# %%
del df_location

# %%
 df_incidentdevice = pd.read_csv('gs://aes-datahub-0001-raw/OMS/2002-2020/IPL/HIS_INCIDENT_DEVICE_IPL.csv', sep = '|', encoding = "ISO-8859-1")

# %%
df_incidentdevice['Date'] = pd.to_datetime(df_incidentdevice['CREATION_DATETIME']).dt.date
df_incidentdevice['Date'] = pd.to_datetime(df_incidentdevice['Date'])

# %%
df_incidentdevice = df_incidentdevice[df_incidentdevice['Date'] >= pd.to_datetime('2020-01-01')]

# %%
print(df_incidentdevice.INCIDENT_DEVICE_ID.nunique())
print(df_incidentdevice.INCIDENT_ID.nunique())
print(df_incidentdevice.STRCTUR_NO.nunique())
print(df_incidentdevice.CIRCT_ID.nunique())
print(df_incidentdevice.DNI_EQUIP_TYPE.nunique())
# Out:
# 38033
# 32132
# 20654
# 427
# 31
