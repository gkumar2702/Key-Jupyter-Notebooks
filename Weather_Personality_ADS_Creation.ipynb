# %%
import csv
import math
import time
import warnings
import operator
import statistics
import requests
import json
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from dateutil.parser import parse
from datetime import datetime
from datetime import date, timedelta
from scipy import stats
from IPython.display import display_html
from multiprocessing import Pool
from sklearn.model_selection import train_test_split

plt.style.use('fivethirtyeight')
warnings.filterwarnings('ignore')
# %matplotlib inline

pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.options.display.float_format = '{:.6f}'.format

# %%
# df1 = pd.read_csv('gs://aes-datahub-0002-curated/Outage_Restoration/Historical_Data/Weather_Data_2020_Hourly/IPL_Weather_Data2020_Hour_500.csv')
# df2 = pd.read_csv('gs://aes-datahub-0002-curated/Outage_Restoration/Historical_Data/Weather_Data_2020_Hourly/IPL_Weather_Data2020_Hour_1000.csv')
# df3 = pd.read_csv('gs://aes-datahub-0002-curated/Outage_Restoration/Historical_Data/Weather_Data_2020_Hourly/IPL_Weather_Data2020_Hour_1500.csv')
# df4 = pd.read_csv('gs://aes-datahub-0002-curated/Outage_Restoration/Historical_Data/Weather_Data_2020_Hourly/IPL_Weather_Data2020_Hour_2000.csv')
# df5 = pd.read_csv('gs://aes-analytics-0002-curated/Outage_Restoration/Historical_Data/Weather_Data_2020_Hourly/IPL_Weather_Data2020_Hour_3000.csv')
# df6 = pd.read_csv('gs://aes-analytics-0002-curated/Outage_Restoration/Historical_Data/Weather_Data_2020_Hourly/IPL_Weather_Data2020_Hour_4000.csv')
# df7 = pd.read_csv('gs://aes-analytics-0002-curated/Outage_Restoration/Historical_Data/Weather_Data_2020_Hourly/IPL_Weather_Data2020_Hour_5000.csv')

# %%
# print(df1.shape)
# print(df2.shape)
# print(df3.shape)
# print(df4.shape)
# print(df5.shape)
# print(df6.shape)
# print(df7.shape)

# %%
# df_ads = pd.concat([df1, df2, df3, df4, df5, df6, df7],ignore_index=True)
# df_ads.drop_duplicates(keep='first', inplace=True)
# print(df_ads.shape)

# %%
df_ads = pd.read_csv('gs://aes-analytics-0002-curated/Outage_Restoration/Historical_Data/Weather_Data_2020_Hourly/IPL_Weather_Marker_ALL_11052020.csv')

# %%
print(list(df_ads.columns))
# Out:
# ['latitude', 'longitude', 'timestamp', 'cldCvr', 'dewPt', 'feelsLike', 'heatIndex', 'mslPres', 'precip', 'presTend', 'radSolar', 'relHum', 'sfcPres', 'snowfall', 'spcHum', 'temp', 'windChill', 'windDir', 'windDir80m', 'windDir100m', 'windSpd', 'windSpd80m', 'windSpd100m', 'wetBulb']

# %%
df_ads.drop(['timestamp', 'presTend'], axis=1, inplace=True)

# %%
df_ads.head()
# Out:
#    latitude  longitude  cldCvr     dewPt  feelsLike  heatIndex     mslPres   precip  radSolar    relHum    sfcPres  snowfall   spcHum      temp  windChill    windDir  windDir80m  windDir100m   windSpd  windSpd80m  windSpd100m   wetBulb
# 0 39.961300 -86.403400      53 21.400000  14.200000  25.700000 1025.600000 0.000000  0.000000 83.700000 989.100000  0.000000 2.500000 25.700000  14.200000 106.600000  108.200000   108.200000 13.300000   16.100000    15.900000 24.300000
# 1 39.961300 -86.403400      52 20.500000  12.600000  24.600000 1025.700000 0.000000  0.000000 84.000000 989.000000  0.000000 2.400000 24.600000  12.600000 112.600000  113.600000   113.600000 13.700000   16.700000    16.500000 23.300000
# 2 39.961300 -86.403400      60 20.400000  12.600000  24.500000 1025.600000 0.000000  0.000000 84.200000 988.900000  0.000000 2.400000 24.500000  12.600000 108.600000  111.600000   111.600000 13.400000   16.500000    16.300000 23.200000
# ...

# %%
df_ads.to_csv('gs://aes-analytics-0002-curated/Outage_Restoration/Historical_Data/Weather_Data_2020_Hourly/IPL_Weather_Personality_All_11052020.csv', index=False)
