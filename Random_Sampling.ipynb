# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('gs://aes-datahub-0002-curated/Outage_Restoration/Historical_Data/Master_Dataset/OMS_IPL_OUTAGE_DATASET_storm_V10.3.csv')

# %%
df_sample = df.sample(n = 2000)
df_sample.reset_index(drop=True, inplace=True)

# %%
df_sample.to_csv('gs://aes-datahub-0002-curated/Outage_Restoration/Historical_Data/Master_Dataset/OMS_IPL_OUTAGE_DATASET_storm_V10.3_sample.csv')
